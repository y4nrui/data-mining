# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t onedork -ofs 11 -cellw 1400 -T -N -kl

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("data/resale-flat-prices/resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv")

# %%
data
# Out:
#          month        town         flat_type block        street_name  \
# 0      2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1      2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2      2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3      2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4      2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...        ...         ...               ...   ...                ...
# 75468  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 75469  2020-07      YISHUN         EXECUTIVE   614       YISHUN ST 61
# 75470  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 75471  2020-07      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 75472  2020-07      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %% [markdown]
# # EDA

# %%
# check for missing values
data.isnull().any()
# Out:
# month                  False
# town                   False
# flat_type              False
# block                  False
# street_name            False
# storey_range           False
# floor_area_sqm         False
# flat_model             False
# lease_commence_date    False
# remaining_lease        False
# resale_price           False
# dtype: bool

# %%
# unique values of town column
data['town'].value_counts()
# Out:
# SENGKANG           5926
# WOODLANDS          5751
# JURONG WEST        5685
# YISHUN             5307
# TAMPINES           4850
# PUNGGOL            4725
# BEDOK              4063
# HOUGANG            3573
# ANG MO KIO         3410
# CHOA CHU KANG      3149
# BUKIT PANJANG      2969
# BUKIT MERAH        2944
# BUKIT BATOK        2805
# TOA PAYOH          2502
# PASIR RIS          2245
# KALLANG/WHAMPOA    2153
# SEMBAWANG          2008
# QUEENSTOWN         1992
# GEYLANG            1820
# JURONG EAST        1681
# CLEMENTI           1674
# SERANGOON          1508
# BISHAN             1455
# CENTRAL AREA        623
# MARINE PARADE       442
# BUKIT TIMAH         213
# Name: town, dtype: int64

# %%
data['flat_type'].value_counts()
# Out:
# 4 ROOM              31258
# 5 ROOM              18674
# 3 ROOM              18309
# EXECUTIVE            5999
# 2 ROOM               1162
# 1 ROOM                 37
# MULTI-GENERATION       34
# Name: flat_type, dtype: int64

# %%
# histogram of resale_price
sns.distplot(data['resale_price'])

# %%
# check for multicollinearity
# resale_price and floor_area_sqm are related
sns.pairplot(data, hue='town', diag_kind='hist')

# %%
# timeseries of resale_price
plt.plot(data['month'], data['resale_price'])
plt.show()
