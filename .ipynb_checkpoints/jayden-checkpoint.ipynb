# %%
# !jt -l
# Out:
# Available Themes:
#    chesterish
#    grade3
#    gruvboxd
#    gruvboxl
#    monokai
#    oceans16
#    onedork
#    solarizedd
#    solarizedl

# %%
# !jt -t chesterish -ofs 11 -cellw 1400 -T -N -kl

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pickle

# %%
t1 = pd.read_csv("data/resale-flat-prices/resale-flat-prices-based-on-registration-date-from-jan-2017-onwards.csv")
t1
# Out:
#          month        town         flat_type block        street_name  \
# 0      2017-01  ANG MO KIO            2 ROOM   406  ANG MO KIO AVE 10
# 1      2017-01  ANG MO KIO            3 ROOM   108   ANG MO KIO AVE 4
# 2      2017-01  ANG MO KIO            3 ROOM   602   ANG MO KIO AVE 5
# 3      2017-01  ANG MO KIO            3 ROOM   465  ANG MO KIO AVE 10
# 4      2017-01  ANG MO KIO            3 ROOM   601   ANG MO KIO AVE 5
# ...        ...         ...               ...   ...                ...
# 75468  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 75469  2020-07      YISHUN         EXECUTIVE   614       YISHUN ST 61
# 75470  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 75471  2020-07      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 75472  2020-07      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
t2 = pd.read_csv("data/resale-flat-prices/resale-flat-prices-based-on-registration-date-from-jan-2015-to-dec-2016.csv")
t2
# Out:
#          month        town         flat_type block        street_name  \
# 0      2015-01  ANG MO KIO            3 ROOM   174   ANG MO KIO AVE 4
# 1      2015-01  ANG MO KIO            3 ROOM   541  ANG MO KIO AVE 10
# 2      2015-01  ANG MO KIO            3 ROOM   163   ANG MO KIO AVE 4
# 3      2015-01  ANG MO KIO            3 ROOM   446  ANG MO KIO AVE 10
# 4      2015-01  ANG MO KIO            3 ROOM   557  ANG MO KIO AVE 10
# ...        ...         ...               ...   ...                ...
# 37148  2016-12      YISHUN            5 ROOM   297       YISHUN ST 20
# 37149  2016-12      YISHUN            5 ROOM   838       YISHUN ST 81
# 37150  2016-12      YISHUN         EXECUTIVE   664       YISHUN AVE 4
# 37151  2016-12      YISHUN         EXECUTIVE   325        YISHUN CTRL
# 37152  2016-12      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
data = pd.read_csv("data/from-jan-2015-onward.csv")

# %%
data
# Out:
#           month        town         flat_type block        street_name  \
# 0       2015-01  ANG MO KIO            3 ROOM   174   ANG MO KIO AVE 4
# 1       2015-01  ANG MO KIO            3 ROOM   541  ANG MO KIO AVE 10
# 2       2015-01  ANG MO KIO            3 ROOM   163   ANG MO KIO AVE 4
# 3       2015-01  ANG MO KIO            3 ROOM   446  ANG MO KIO AVE 10
# 4       2015-01  ANG MO KIO            3 ROOM   557  ANG MO KIO AVE 10
# ...         ...         ...               ...   ...                ...
# 112621  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 112622  2020-07      YISHUN         EXECUTIVE   614       YISHUN ST 61
# 112623  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 112624  2020-07      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 112625  2020-07      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %% [markdown]
# # EDA and Preprocessing

# %%
data.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# dtype: int64

# %%
# check for missing values
data.isnull().any()
# Out:
# month                  False
# town                   False
# flat_type              False
# block                  False
# street_name            False
# storey_range           False
# floor_area_sqm         False
# flat_model             False
# lease_commence_date    False
# remaining_lease        False
# resale_price           False
# dtype: bool

# %%
# unique values of town column
data['town'].value_counts()
# Out:
# JURONG WEST        8573
# SENGKANG           8545
# WOODLANDS          8350
# TAMPINES           7516
# YISHUN             7461
# BEDOK              6505
# PUNGGOL            6275
# HOUGANG            5482
# ANG MO KIO         5261
# CHOA CHU KANG      4919
# BUKIT PANJANG      4367
# BUKIT MERAH        4309
# BUKIT BATOK        4306
# TOA PAYOH          3597
# PASIR RIS          3430
# KALLANG/WHAMPOA    3298
# SEMBAWANG          3022
# QUEENSTOWN         2963
# GEYLANG            2852
# CLEMENTI           2607
# JURONG EAST        2513
# SERANGOON          2334
# BISHAN             2140
# CENTRAL AREA       1033
# MARINE PARADE       667
# BUKIT TIMAH         301
# Name: town, dtype: int64

# %%
data['flat_type'].value_counts()
# Out:
# 4 ROOM              46448
# 3 ROOM              28330
# 5 ROOM              27409
# EXECUTIVE            8839
# 2 ROOM               1510
# 1 ROOM                 51
# MULTI-GENERATION       39
# Name: flat_type, dtype: int64

# %%
data['flat_model'].value_counts()
# Out:
# Model A                   35814
# Improved                  28359
# New Generation            16800
# Premium Apartment         11638
# Simplified                 5061
# Apartment                  4465
# Standard                   3300
# Maisonette                 3257
# Model A2                   1582
# DBSS                       1412
# Type S1                     266
# Model A-Maisonette          196
# Adjoined flat               191
# Type S2                     124
# Terrace                      66
# Multi Generation             39
# Premium Apartment Loft       26
# Improved-Maisonette          17
# Premium Maisonette           10
# 2-room                        3
# Name: flat_model, dtype: int64

# %%
# histogram of resale_price
sns.distplot(data['resale_price'])

# %%
# check for multicollinearity
# resale_price and floor_area_sqm are related
sns.pairplot(data, hue='town', diag_kind='hist')

# %%
sns.heatmap(data.corr(),annot=True, cmap='coolwarm')

# %%
sns.boxplot(data=data)

# %%
fig=sns.countplot(x=data['storey_range'])
plt.figure(figsize=(50,15))
fig.set_xticklabels(fig.get_xticklabels(), rotation=45)
# Out:
# [Text(0, 0, '07 TO 09'),
#  Text(0, 0, '01 TO 03'),
#  Text(0, 0, '13 TO 15'),
#  Text(0, 0, '10 TO 12'),
#  Text(0, 0, '04 TO 06'),
#  Text(0, 0, '19 TO 21'),
#  Text(0, 0, '16 TO 18'),
#  Text(0, 0, '22 TO 24'),
#  Text(0, 0, '25 TO 27'),
#  Text(0, 0, '28 TO 30'),
#  Text(0, 0, '34 TO 36'),
#  Text(0, 0, '46 TO 48'),
#  Text(0, 0, '31 TO 33'),
#  Text(0, 0, '37 TO 39'),
#  Text(0, 0, '43 TO 45'),
#  Text(0, 0, '40 TO 42'),
#  Text(0, 0, '49 TO 51')]

# %%
data.describe()
# Out:
#        floor_area_sqm  lease_commence_date  remaining_lease  resale_price
# count   112626.000000        112626.000000    112626.000000  1.126260e+05
# mean        97.402861          1992.962753        74.417756  4.378528e+05
# std         24.254935            12.233117        12.147466  1.477767e+05
# min         31.000000          1966.000000        45.500000  1.400000e+05
# 25%         77.000000          1984.000000        65.166667  3.330000e+05
# 50%         95.000000          1992.000000        73.791667  4.080000e+05
# 75%        112.000000          2002.000000        83.416667  5.060000e+05
# max        280.000000          2018.000000        97.083333  1.232000e+06

# %%
# timeseries of resale_price
plt.plot(data['month'], data['resale_price'])
plt.figure(figsize=(100,100))
plt.show()

# %%
fig = sns.boxplot(x='month', y='resale_price', data=data)

# %%
data['town'].value_counts()
# Out:
# JURONG WEST        8573
# SENGKANG           8545
# WOODLANDS          8350
# TAMPINES           7516
# YISHUN             7461
# BEDOK              6505
# PUNGGOL            6275
# HOUGANG            5482
# ANG MO KIO         5261
# CHOA CHU KANG      4919
# BUKIT PANJANG      4367
# BUKIT MERAH        4309
# BUKIT BATOK        4306
# TOA PAYOH          3597
# PASIR RIS          3430
# KALLANG/WHAMPOA    3298
# SEMBAWANG          3022
# QUEENSTOWN         2963
# GEYLANG            2852
# CLEMENTI           2607
# JURONG EAST        2513
# SERANGOON          2334
# BISHAN             2140
# CENTRAL AREA       1033
# MARINE PARADE       667
# BUKIT TIMAH         301
# Name: town, dtype: int64

# %%
data[data['resale_price'] == '']

# %%
data['resale_price'].mean()
# Out:
# 437852.7906088291

# %%
# box plot of town to resale_price
plt.figure(figsize=((50,15)))
fig = sns.boxplot(x='town', y='resale_price', data=data)

# %%
# box plot of flat_model to resale prices
plt.figure(figsize=(50,15))
fig = sns.boxplot(x='flat_model', y='resale_price', data=data)

# %%
plt.figure(figsize=(50,15))
sns.countplot(data['flat_model'])

# %%
# box plot of flat_type to resale prices
plt.figure(figsize=(50,15))
fig = sns.boxplot(x='flat_type', y='resale_price', data=data)

# %%
data['flat_type'].value_counts()
# Out:
# 4 ROOM              46448
# 3 ROOM              28330
# 5 ROOM              27409
# EXECUTIVE            8839
# 2 ROOM               1510
# 1 ROOM                 51
# MULTI-GENERATION       39
# Name: flat_type, dtype: int64

# %% [markdown]
# ## EDA

# %%
scaled_data = pd.read_excel('./data/from-jan-2015-onward-scaled.xlsx', index_col=)

# %%
scaled_data3 = pd.read_csv('./data/from-jan-2015-onward-scaled.csv')

# %%
scaled_data3
# Out:
#         Unnamed: 0    month        town         flat_type block  \
# 0                0  2015-01  ANG MO KIO            3 ROOM   174
# 1                1  2015-01  ANG MO KIO            3 ROOM   541
# 2                2  2015-01  ANG MO KIO            3 ROOM   163
# 3                3  2015-01  ANG MO KIO            3 ROOM   446
# 4                4  2015-01  ANG MO KIO            3 ROOM   557
# ...            ...      ...         ...               ...   ...
# 112621      112621  2020-07      YISHUN         EXECUTIVE   643
# 112622      112622  2020-07      YISHUN         EXECUTIVE   614
# 112623      112623  2020-07      YISHUN         EXECUTIVE   643
# 112624      112624  2020-07      YISHUN         EXECUTIVE   724
# 112625      112625  2020-07      YISHUN  MULTI-GENERATION   633
#
#               street_name  storey_range  floor_area_sqm        flat_model  \
# 0        ANG MO KIO AVE 4             8            60.0          Improved
# ...

# %%
scaled_data2.reset_index(drop=True)
# Out:
#         Unnamed: 0    month        town         flat_type block  \
# 0                0  2015-01  ANG MO KIO            3 ROOM   174
# 1                1  2015-01  ANG MO KIO            3 ROOM   541
# 2                2  2015-01  ANG MO KIO            3 ROOM   163
# 3                3  2015-01  ANG MO KIO            3 ROOM   446
# 4                4  2015-01  ANG MO KIO            3 ROOM   557
# ...            ...      ...         ...               ...   ...
# 112621      112621  2020-07      YISHUN         EXECUTIVE   643
# 112622      112622  2020-07      YISHUN         EXECUTIVE   614
# 112623      112623  2020-07      YISHUN         EXECUTIVE   643
# 112624      112624  2020-07      YISHUN         EXECUTIVE   724
# 112625      112625  2020-07      YISHUN  MULTI-GENERATION   633
#
#               street_name  storey_range  floor_area_sqm        flat_model  \
# 0        ANG MO KIO AVE 4             8            60.0          Improved
# ...

# %%
scaled_data = scaled_data2.drop(columns=['Unnamed: 0'], axis=1)

# %%
scaled_data
# Out:
#           month        town         flat_type block        street_name  \
# 0       2015-01  ANG MO KIO            3 ROOM   174   ANG MO KIO AVE 4
# 1       2015-01  ANG MO KIO            3 ROOM   541  ANG MO KIO AVE 10
# 2       2015-01  ANG MO KIO            3 ROOM   163   ANG MO KIO AVE 4
# 3       2015-01  ANG MO KIO            3 ROOM   446  ANG MO KIO AVE 10
# 4       2015-01  ANG MO KIO            3 ROOM   557  ANG MO KIO AVE 10
# ...         ...         ...               ...   ...                ...
# 112621  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 112622  2020-07      YISHUN         EXECUTIVE   614       YISHUN ST 61
# 112623  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 112624  2020-07      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 112625  2020-07      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#         storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
scaled_data.to_csv('./data/from-jan-2015-onward-scaled.csv')

# %% [markdown]
# ## Standardization and Transformation

# %%
plt.figure(figsize=((50,15)))
sns.boxplot('resale_price', data=data)

# %%
sns.distplot(data['resale_price'])

# %%
sns.distplot(np.log(data['resale_price']))

# %%
round(data.describe(), 3)
# Out:
#        floor_area_sqm  lease_commence_date  remaining_lease  resale_price
# count      112626.000           112626.000       112626.000    112626.000
# mean           97.403             1992.963           74.418    437852.791
# std            24.255               12.233           12.147    147776.713
# min            31.000             1966.000           45.500    140000.000
# 25%            77.000             1984.000           65.167    333000.000
# 50%            95.000             1992.000           73.792    408000.000
# 75%           112.000             2002.000           83.417    506000.000
# max           280.000             2018.000           97.083   1232000.000

# %%
import time

start = time.time()

## insert test code here

end = time.time()

runtime = end - start

print(runtime)
# Out:
# 2.5987625122070312e-05

# %%
# check for skewness
data.hist()
plt.tight_layout()

# %%
from sklearn.preprocessing import StandardScaler
from scipy import stats

ss = StandardScaler()

data_scaled = pd.DataFrame(ss.fit_transform(data[['floor_area_sqm', 'lease_commence_date', 'remaining_lease', 'resale_price']]))

# %%
data_scaled
# Out:
#                0         1         2         3
# 0      -1.542079 -0.569175 -0.363679 -1.237364
# 1      -1.212248 -0.977903 -0.775289 -1.102024
# 2      -1.171019 -1.059649 -0.857611 -1.034354
# 3      -1.212248 -1.141395 -0.939933 -1.000519
# 4      -1.212248 -1.059649 -0.857611 -1.000519
# ...          ...       ...       ...       ...
# 112621  2.003607 -0.487429 -0.672386  0.928075
# 112622  2.003607 -0.487429 -0.706687  0.886715
# 112623  1.838691 -0.487429 -0.679247  0.691230
# 112624  1.962378 -0.569175 -0.775289  0.657395
# 112625  3.034330 -0.487429 -0.658666  2.281474
#
# [112626 rows x 4 columns]

# %%
data['storey_range'].value_counts()
# Out:
# 04 TO 06    26487
# 07 TO 09    24176
# 10 TO 12    21384
# 01 TO 03    20583
# 13 TO 15    10228
# 16 TO 18     4486
# 19 TO 21     1908
# 22 TO 24     1394
# 25 TO 27      754
# 28 TO 30      477
# 34 TO 36      208
# 31 TO 33      200
# 37 TO 39      196
# 40 TO 42      102
# 46 TO 48       20
# 43 TO 45       14
# 49 TO 51        9
# Name: storey_range, dtype: int64

# %% [markdown]
# ## Geocoding

# %% [markdown]
# ## Modelling

# %%
# multi linear regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
from onemapsg import OneMapClient

Client = OneMapClient("YOUR_EMAIL", "YOUR_PASSWORD")

def findLongLat(address,block):
    t=Client.search(address)
    for i in t['results']:
        if i['BLK_NO']==block:
            return (i['LATITUDE'],i['LONGITUDE'])
    return np.nan,np.nan


      
# data['LATITUDE']=np.nan
# data['LONGITUDE']=np.nan  
# for row in range(len(data)):

#      data.LATITUDE.loc[row],data.LONGITUDE.loc[row]=findLongLat(data.street_name.loc[row],data.block.loc[row])

# %%
data['new_address'] = data[['block', 'street_name']].apply(lambda row: " ".join(row.values.astype(str)), axis=1)

# %%
data.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986             70.0
# 1            68.0  New Generation                 1981             65.0
# 2            69.0  New Generation                 1980             64.0
# 3            68.0  New Generation                 1979             63.0
# 4            68.0  New Generation                 1980             64.0
#
#    resale_price            new_address
# 0      255000.0   174 ANG MO KIO AVE 4
# ...

# %%
data['street_name'].value_counts()
# Out:
# YISHUN RING RD        1792
# BEDOK RESERVOIR RD    1378
# ANG MO KIO AVE 10     1274
# ANG MO KIO AVE 3      1186
# PUNGGOL FIELD         1146
#                       ...
# HOUGANG ST 32            4
# BT MERAH LANE 1          4
# KRETA AYER RD            3
# SEMBAWANG WAY            2
# TAMPINES ST 86           1
# Name: street_name, Length: 546, dtype: int64

# %%
import pickle
temp = pd.DataFrame(data['new_address'])
# pickle.dump(temp, open('pickle/new_address.pkl', 'wb'))

# %%
# geocoding new_address
street_with_block_dict = pickle.load(open("./pickle/street_with_block_dict.pkl", 'rb'))

# %%
street_with_block_dict
# Out:
# {'174 ANG MO KIO AVE 4': ('1.375097469', '103.83761899999999'),
#  '541 ANG MO KIO AVE 10': ('1.3739223919999999', '103.8556214'),
#  '163 ANG MO KIO AVE 4': ('1.373548539', '103.8381765'),
#  '446 ANG MO KIO AVE 10': ('1.367760951', '103.8553571'),
#  '557 ANG MO KIO AVE 10': ('1.3716257019999998', '103.8577361'),
#  '603 ANG MO KIO AVE 5': ('1.38020079', '103.8357557'),
#  '709 ANG MO KIO AVE 8': ('1.3711372080000002', '103.8476623'),
#  '333 ANG MO KIO AVE 1': ('1.3613425559999999', '103.85169859999999'),
#  '109 ANG MO KIO AVE 4': ('1.370096538', '103.8376878'),
#  '564 ANG MO KIO AVE 3': ('1.369848376', '103.85940409999999'),
#  '218 ANG MO KIO AVE 1': ('1.365119086', '103.84174250000001'),
#  '556 ANG MO KIO AVE 10': ('1.3720323630000002', '103.8576254'),
#  '156 ANG MO KIO AVE 4': ('1.375495196', '103.8399475'),
#  '471 ANG MO KIO AVE 10': ('1.363466006', '103.85670290000002'),
#  '434 ANG MO KIO AVE 10': ('1.367891507', '103.85345500000001'),
# ...

# %%
data
# Out:
#           month        town         flat_type block        street_name  \
# 0       2015-01  ANG MO KIO            3 ROOM   174   ANG MO KIO AVE 4
# 1       2015-01  ANG MO KIO            3 ROOM   541  ANG MO KIO AVE 10
# 2       2015-01  ANG MO KIO            3 ROOM   163   ANG MO KIO AVE 4
# 3       2015-01  ANG MO KIO            3 ROOM   446  ANG MO KIO AVE 10
# 4       2015-01  ANG MO KIO            3 ROOM   557  ANG MO KIO AVE 10
# ...         ...         ...               ...   ...                ...
# 112621  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 112622  2020-07      YISHUN         EXECUTIVE   614       YISHUN ST 61
# 112623  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 112624  2020-07      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 112625  2020-07      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
def geocode(add):
    res = street_with_block_dict[add]
    return res

# %%
geocode('174 ANG MO KIO AVE 4')
# Out:
# ('1.375097469', '103.83761899999999')

# %%
temp_df = pickle.load(open('./pickle/address_with_geocode_df.pkl', 'rb'))
temp_df
# Out:
#                   new_address            latitude           longitude
# 0        174 ANG MO KIO AVE 4         1.375097469  103.83761899999999
# 1       541 ANG MO KIO AVE 10  1.3739223919999999         103.8556214
# 2        163 ANG MO KIO AVE 4         1.373548539         103.8381765
# 3       446 ANG MO KIO AVE 10         1.367760951         103.8553571
# 4       557 ANG MO KIO AVE 10  1.3716257019999998         103.8577361
# ...                       ...                 ...                 ...
# 112621       643 YISHUN ST 61         1.421335159          103.837437
# 112622       614 YISHUN ST 61  1.4198290669999998         103.8360325
# 112623       643 YISHUN ST 61         1.421335159          103.837437
# 112624       724 YISHUN ST 71         1.426474819         103.8299159
# 112625       633 YISHUN ST 61         1.418657574         103.8398421
#
# [112626 rows x 3 columns]

# %%
temp_df = temp_df[['latitude', 'longitude']]

# %%
temp_df
# Out:
#                   latitude           longitude
# 0              1.375097469  103.83761899999999
# 1       1.3739223919999999         103.8556214
# 2              1.373548539         103.8381765
# 3              1.367760951         103.8553571
# 4       1.3716257019999998         103.8577361
# ...                    ...                 ...
# 112621         1.421335159          103.837437
# 112622  1.4198290669999998         103.8360325
# 112623         1.421335159          103.837437
# 112624         1.426474819         103.8299159
# 112625         1.418657574         103.8398421
#
# [112626 rows x 2 columns]

# %%
new_data = pd.concat([data, temp_df], axis=1)

# %%
new_data
# Out:
#           month        town         flat_type block        street_name  \
# 0       2015-01  ANG MO KIO            3 ROOM   174   ANG MO KIO AVE 4
# 1       2015-01  ANG MO KIO            3 ROOM   541  ANG MO KIO AVE 10
# 2       2015-01  ANG MO KIO            3 ROOM   163   ANG MO KIO AVE 4
# 3       2015-01  ANG MO KIO            3 ROOM   446  ANG MO KIO AVE 10
# 4       2015-01  ANG MO KIO            3 ROOM   557  ANG MO KIO AVE 10
# ...         ...         ...               ...   ...                ...
# 112621  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 112622  2020-07      YISHUN         EXECUTIVE   614       YISHUN ST 61
# 112623  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 112624  2020-07      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 112625  2020-07      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
new_data.to_csv('./data/df_with_long_lat_values.csv')

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112626 entries, 0 to 112625
# Data columns (total 14 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                112626 non-null  object
#  1   town                 112626 non-null  object
#  2   flat_type            112626 non-null  object
#  3   block                112626 non-null  object
#  4   street_name          112626 non-null  object
#  5   storey_range         112626 non-null  object
#  6   floor_area_sqm       112626 non-null  float64
#  7   flat_model           112626 non-null  object
#  8   lease_commence_date  112626 non-null  int64
#  9   remaining_lease      112626 non-null  float64
#  10  resale_price         112626 non-null  float64
#  11  new_address          112626 non-null  object
#  12  latitude             112626 non-null  object
#  13  longitude            112626 non-null  object
# dtypes: float64(3), int64(1), object(10)
# ...

# %%
new_data
# Out:
#           month        town         flat_type block        street_name  \
# 0       2015-01  ANG MO KIO            3 ROOM   174   ANG MO KIO AVE 4
# 1       2015-01  ANG MO KIO            3 ROOM   541  ANG MO KIO AVE 10
# 2       2015-01  ANG MO KIO            3 ROOM   163   ANG MO KIO AVE 4
# 3       2015-01  ANG MO KIO            3 ROOM   446  ANG MO KIO AVE 10
# 4       2015-01  ANG MO KIO            3 ROOM   557  ANG MO KIO AVE 10
# ...         ...         ...               ...   ...                ...
# 112621  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 112622  2020-07      YISHUN         EXECUTIVE   614       YISHUN ST 61
# 112623  2020-07      YISHUN         EXECUTIVE   643       YISHUN ST 61
# 112624  2020-07      YISHUN         EXECUTIVE   724       YISHUN ST 71
# 112625  2020-07      YISHUN  MULTI-GENERATION   633       YISHUN ST 61
#
#        storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
scaled_data = pd.read_csv('./data/from-jan-2015-onward-scaled.csv')

# %%
sns.distplot(scaled_data['scaled_resale_price'])

# %%
sns.distplot(np.log(scaled_data['scaled_resale_price']))
# Out:
# /Users/ninja/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py:679: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
sns.distplot(scaled_data['resale_price'])

# %%
sns.distplot(np.log(scaled_data['resale_price']))
